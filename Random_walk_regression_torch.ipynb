# %% [markdown]
#  ## Packages

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
import sys

# %%
print(f"Python version -> {sys.version}")  # 3.12.3
print(f"torch version -> {torch.__version__}")  # 2.8.0+cu128
# Out:
# Python version -> 3.12.3 (main, Aug 14 2025, 17:47:21) [GCC 13.3.0]
# torch version -> 2.8.0+cu128

# %% [markdown]
#  ## Generate a random walk

# %%
def random_walk(steps, scale=1):
    w = np.zeros(steps)
    for x in range(1, steps):
        w[x] = w[x - 1] + scale * np.random.normal()
    return w


time_steps = 5000
data = pd.DataFrame(
    {
        "x": range(time_steps),
        "y": np.arange(time_steps) ** (1 / 2) + random_walk(time_steps),
    }
)
data = data.assign(z=np.log(data.x + 1) + 0.3 * data.y)
data_mat = np.array(data)

plt.plot(data_mat[:, 0], data_mat[:, 2], c="goldenrod")
plt.title("Synthetic Random Walk Data")
plt.show()

# %% [markdown]
# $$
# \begin{align}
# x_t &= t \\
# y_t &= \sqrt{t} + W_t \\
# z_t &= \log(t + 1) + 0.3 y_t
# \end{align}
# $$

# %% [markdown]
#  ## Prepare Sliding Window Data

# %%
samples = []
target = []
length = 50  # sequence length
test_size = 1000

for i in range(time_steps - length):
    sample = data_mat[i : i + length, :2]
    outcome = data_mat[i + length, 2]
    samples.append(sample)
    target.append(outcome)

# Convert to arrays
samples = np.array(samples)
target = np.array(target)

# Train/test split
x_train = samples[:-test_size]
x_test = samples[-test_size:]
y_train = target[:-test_size]
y_test = target[-test_size:]

print("x_train:", x_train.shape)
print("x_test :", x_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# x_train: (3950, 50, 2)
# x_test : (1000, 50, 2)
# y_train: (3950,)
# y_test : (1000,)

# %% [markdown]
#  ## Convert to PyTorch tensors

# %%
x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1)
x_test_tensor = torch.tensor(x_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1)

train_dataset = TensorDataset(x_train_tensor, y_train_tensor)
test_dataset = TensorDataset(x_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=25, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=25, shuffle=False)

# %% [markdown]
#  ## Define RNN Model

# %%
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, dense1, dense2, dense3):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(
            input_size=input_size,
            hidden_size=hidden_size,
            batch_first=True,
            nonlinearity="relu",
        )
        self.dropout = nn.Dropout(0.1)
        self.fc1 = nn.Linear(hidden_size, dense1)
        self.fc2 = nn.Linear(dense1, dense2)
        self.fc3 = nn.Linear(dense2, dense3)
        self.out = nn.Linear(dense3, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        out, _ = self.rnn(x)
        out = out[:, -1, :]  # take the last hidden state
        out = self.dropout(self.relu(self.fc1(out)))
        out = self.dropout(self.relu(self.fc2(out)))
        out = self.dropout(self.relu(self.fc3(out)))
        out = self.out(out)
        return out


input_size = 2
hidden_size = 128
model = RNNModel(input_size, hidden_size, 64, 16, 16)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(model)
# Out:
# RNNModel(
#   (rnn): RNN(2, 128, batch_first=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=128, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=16, bias=True)
#   (out): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
#  ## Train the Model (with early stopping)

# %%
epochs = 50
patience = 15
best_val_loss = np.inf
patience_counter = 0

train_losses = []
val_losses = []

for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for x_batch, y_batch in train_loader:
        x_batch, y_batch = x_batch.to(device), y_batch.to(device)
        optimizer.zero_grad()
        outputs = model(x_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    train_loss = running_loss / len(train_loader)
    train_losses.append(train_loss)

    # Validation
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for x_val, y_val in test_loader:
            x_val, y_val = x_val.to(device), y_val.to(device)
            outputs = model(x_val)
            loss = criterion(outputs, y_val)
            val_loss += loss.item()
    val_loss /= len(test_loader)
    val_losses.append(val_loss)

    print(
        f"Epoch [{epoch+1}/{epochs}] Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}"
    )

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        best_model_state = model.state_dict()
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered!")
            break

# Load best model
model.load_state_dict(best_model_state)
# Out:
# Epoch [1/50] Train Loss: 30.4573 | Val Loss: 286.5843
# Epoch [2/50] Train Loss: 26.7884 | Val Loss: 161.5517
# Epoch [3/50] Train Loss: 22.8943 | Val Loss: 42.1769
# Epoch [4/50] Train Loss: 7.7402 | Val Loss: 24.8180
# Epoch [5/50] Train Loss: 5072.7178 | Val Loss: 28.0553
# Epoch [6/50] Train Loss: 5.1670 | Val Loss: 30.2197
# Epoch [7/50] Train Loss: 4.7416 | Val Loss: 32.1220
# Epoch [8/50] Train Loss: 3.8878 | Val Loss: 20.1266
# Epoch [9/50] Train Loss: 3.4610 | Val Loss: 16.6722
# Epoch [10/50] Train Loss: 3.8615 | Val Loss: 24.6245
# Epoch [11/50] Train Loss: 2.5892 | Val Loss: 15.2083
# Epoch [12/50] Train Loss: 2.3783 | Val Loss: 11.7528
# Epoch [13/50] Train Loss: 2.0984 | Val Loss: 17.3591
# Epoch [14/50] Train Loss: 1.9960 | Val Loss: 7.4674
# Epoch [15/50] Train Loss: 2.1187 | Val Loss: 5.9749
# Epoch [16/50] Train Loss: 1.6411 | Val Loss: 18.0530
# Epoch [17/50] Train Loss: 1.7044 | Val Loss: 10.2597
# Epoch [18/50] Train Loss: 1.8434 | Val Loss: 17.1486
# Epoch [19/50] Train Loss: 1.6723 | Val Loss: 9.2503
# Epoch [20/50] Train Loss: 1.5506 | Val Loss: 17.4824
# Epoch [21/50] Train Loss: 1.4190 | Val Loss: 17.1058
# Epoch [22/50] Train Loss: 1.5354 | Val Loss: 11.0476
# Epoch [23/50] Train Loss: 1.4565 | Val Loss: 18.4287
# Epoch [24/50] Train Loss: 1.3207 | Val Loss: 19.0172
# Epoch [25/50] Train Loss: 1.3369 | Val Loss: 11.2970
# Epoch [26/50] Train Loss: 1.3868 | Val Loss: 12.9996
# Epoch [27/50] Train Loss: 1.2159 | Val Loss: 5.2108
# Epoch [28/50] Train Loss: 1.2751 | Val Loss: 14.4474
# Epoch [29/50] Train Loss: 1.2709 | Val Loss: 19.5879
# Epoch [30/50] Train Loss: 1.3097 | Val Loss: 10.0289
# Epoch [31/50] Train Loss: 1.2442 | Val Loss: 20.6225
# Epoch [32/50] Train Loss: 1.3465 | Val Loss: 10.0929
# Epoch [33/50] Train Loss: 1.3368 | Val Loss: 9.9639
# Epoch [34/50] Train Loss: 1.0970 | Val Loss: 7.5279
# Epoch [35/50] Train Loss: 1.3359 | Val Loss: 12.7272
# Epoch [36/50] Train Loss: 1.2151 | Val Loss: 14.8845
# Epoch [37/50] Train Loss: 1.2798 | Val Loss: 12.8715
# Epoch [38/50] Train Loss: 1.2020 | Val Loss: 11.3323
# Epoch [39/50] Train Loss: 1.2342 | Val Loss: 8.5116
# Epoch [40/50] Train Loss: 1.2820 | Val Loss: 13.4125
# Epoch [41/50] Train Loss: 1.1555 | Val Loss: 6.2212
# Epoch [42/50] Train Loss: 1.1200 | Val Loss: 14.0418
# Early stopping triggered!
# <All keys matched successfully>

# %% [markdown]
#  ## Plot Training History

# %%
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.legend()
plt.title("Training and Validation Loss")
plt.yscale("log")
plt.show()

# %% [markdown]
#  ## Predictions and Plotting

# %%
model.eval()
with torch.no_grad():
    train_preds = model(x_train_tensor.to(device)).cpu().numpy()
    test_preds = model(x_test_tensor.to(device)).cpu().numpy()

plt.figure(figsize=(10, 6))
plt.plot(data["x"], data["z"], c="goldenrod", label="data")
plt.plot(data.iloc[length : -len(y_test)]["x"], train_preds, c="navy", label="train")
plt.plot(data.iloc[-len(y_test) :]["x"], test_preds, c="firebrick", label="test")
plt.legend()
plt.title("Predictions vs Actual Data")
plt.show()
